# %%
import pandas as pd
import itertools
peca = pd.read_excel('CO2_footprint.xlsx')

# %%
peca.head()
# Out:
#           Wagon_type  Upstream_Train_level  Mass_Train_level  EoL_Train_level  \
# 0            MC + MC              319292.0          53111.84         4350.670
# 1        MC + M + MC              460922.0          77284.06         8210.951
# 2       MC + T1 + MC              434933.0          72934.75         8168.670
# 3  MC + M1 + M1 + MC              554504.0          99916.50        12071.450
# 4  MC + T1 + M1 + MC              552539.0          96337.08        12029.060
#
#    Upstream_RCB_window  Mass_RCB_window  EoL_RCB_window  \
# 0                 80.0            54.12               4
# 1                107.6            74.02               6
# 2                107.6            74.02               6
# 3                135.2            93.92               8
# 4                135.2            93.92               8
#
#    Upstream_RDC_seats_couches_tables  Mass_RDC_seats_couches_tables  \
# 0                               2536                          37.72
# ...
